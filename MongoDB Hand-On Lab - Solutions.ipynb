# %% [markdown]
# <a href="https://colab.research.google.com/github/manxuan02/dadt/blob/main/MongoDB%20Hand-On%20Lab%20-%20Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 Setting Up MongoDB Environment

# %%
# Install MongoDB's dependencies
# !sudo wget http://archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2_amd64.deb
# !sudo dpkg -i libssl1.1_1.1.1f-1ubuntu2_amd64.deb

# Import the public key used by the package management system
# !wget -qO - https://www.mongodb.org/static/pgp/server-4.4.asc | apt-key add -

# Create a list file for MongoDB
# !echo "deb [ arch=amd64,arm64 ] http://repo.mongodb.org/apt/ubuntu bionic/mongodb-org/4.4 multiverse" | tee /etc/apt/sources.list.d/mongodb-org-4.4.list

# Reload the local package database
# !apt-get update > /dev/null

# Install the MongoDB packages
# !apt-get install -y mongodb-org > /dev/null

# Install pymongo
# !pip install -q pymongo

# Create Data Folder
# !mkdir -p /data/db

# Start MongoDB
# !mongod --fork --logpath /var/log/mongodb.log --dbpath /data/db
# Out:
# --2025-11-28 11:46:31--  http://archive.ubuntu.com/ubuntu/pool/main/o/openssl/libssl1.1_1.1.1f-1ubuntu2_amd64.deb
# Resolving archive.ubuntu.com (archive.ubuntu.com)... 185.125.190.36, 185.125.190.39, 185.125.190.83, ...
# Connecting to archive.ubuntu.com (archive.ubuntu.com)|185.125.190.36|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1318204 (1.3M) [application/x-debian-package]
# Saving to: ‘libssl1.1_1.1.1f-1ubuntu2_amd64.deb.1’
#
# libssl1.1_1.1.1f-1u 100%[===================>]   1.26M  1.98MB/s    in 0.6s
#
# 2025-11-28 11:46:32 (1.98 MB/s) - ‘libssl1.1_1.1.1f-1ubuntu2_amd64.deb.1’ saved [1318204/1318204]
#
# (Reading database ... 121771 files and directories currently installed.)
# Preparing to unpack libssl1.1_1.1.1f-1ubuntu2_amd64.deb ...
# Unpacking libssl1.1:amd64 (1.1.1f-1ubuntu2) over (1.1.1f-1ubuntu2) ...
# Setting up libssl1.1:amd64 (1.1.1f-1ubuntu2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# Warning: apt-key is deprecated. Manage keyring files in trusted.gpg.d instead (see apt-key(8)).
# OK
# deb [ arch=amd64,arm64 ] http://repo.mongodb.org/apt/ubuntu bionic/mongodb-org/4.4 multiverse
# W: http://repo.mongodb.org/apt/ubuntu/dists/bionic/mongodb-org/4.4/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# about to fork child process, waiting until server is ready for connections.
# forked process: 3440
# ERROR: child process failed, exited with 48
# To see additional information in this output, start without the "--fork" option.

# %%
from pymongo import MongoClient

# Establish connection to MongoDB
try:
    client = MongoClient('localhost', 27017)
    print("Connected to MongoDB")
except Exception as e:
    print("Error connecting to MongoDB: ", e)
    exit()

# List databases to check the connection
try:
    databases = client.list_database_names()
    print("Databases:", databases)
except Exception as e:
    print("Error listing databases: ", e)

# Retrieve server status
try:
    server_status = client.admin.command("serverStatus")
    print("Server Status:", server_status)
except Exception as e:
    print("Error retrieving server status: ", e)

# Perform basic database operations (Create, Read)
try:
    db = client.test_db
    collection = db.test_collection
    # Insert a document
    insert_result = collection.insert_one({"name": "test", "value": 123})
    print("Insert operation result:", insert_result.inserted_id)
    # Read a document
    read_result = collection.find_one({"name": "test"})
    print("Read operation result:", read_result)
except Exception as e:
    print("Error performing database operations: ", e)
# Out:
# Connected to MongoDB
# Databases: ['admin', 'config', 'local']
# Server Status: {'host': '17be74041ce3', 'version': '4.4.29', 'process': 'mongod', 'pid': 2152, 'uptime': 28.0, 'uptimeMillis': 28028, 'uptimeEstimate': 28, 'localTime': datetime.datetime(2025, 11, 28, 11, 46, 49, 493000), 'asserts': {'regular': 0, 'warning': 0, 'msg': 0, 'user': 4, 'rollovers': 0}, 'connections': {'current': 3, 'available': 838857, 'totalCreated': 3, 'active': 2, 'exhaustIsMaster': 0, 'exhaustHello': 0, 'awaitingTopologyChanges': 1}, 'electionMetrics': {'stepUpCmd': {'called': 0, 'successful': 0}, 'priorityTakeover': {'called': 0, 'successful': 0}, 'catchUpTakeover': {'called': 0, 'successful': 0}, 'electionTimeout': {'called': 0, 'successful': 0}, 'freezeTimeout': {'called': 0, 'successful': 0}, 'numStepDownsCausedByHigherTerm': 0, 'numCatchUps': 0, 'numCatchUpsSucceeded': 0, 'numCatchUpsAlreadyCaughtUp': 0, 'numCatchUpsSkipped': 0, 'numCatchUpsTimedOut': 0, 'numCatchUpsFailedWithError': 0, 'numCatchUpsFailedWithNewTerm': 0, 'numCatchUpsFailedWithReplSetAbortPrimaryCatchUpCmd': 0, 'averageCatchUpOps': 0.0}, 'extra_info': {'note': 'fields vary by platform', 'user_time_us': 732903, 'system_time_us': 60165, 'maximum_resident_set_kb': 90500, 'input_blocks': 0, 'output_blocks': 424, 'page_reclaims': 13625, 'page_faults': 1, 'voluntary_context_switches': 1116, 'involuntary_context_switches': 166}, 'featureCompatibilityVersion': {'major': 4, 'minor': 4, 'transitioning': 0}, 'flowControl': {'enabled': True, 'targetRateLimit': 1000000000, 'timeAcquiringMicros': 2, 'locksPerKiloOp': 0.0, 'sustainerRate': 0, 'isLagged': False, 'isLaggedCount': 0, 'isLaggedTimeMicros': 0}, 'globalLock': {'totalTime': 28044000, 'currentQueue': {'total': 0, 'readers': 0, 'writers': 0}, 'activeClients': {'total': 0, 'readers': 0, 'writers': 0}}, 'indexBulkBuilder': {'count': 0, 'filesOpenedForExternalSort': 0, 'filesClosedForExternalSort': 0}, 'locks': {'ParallelBatchWriterMode': {'acquireCount': {'r': 23}}, 'FeatureCompatibilityVersion': {'acquireCount': {'r': 123, 'w': 13}}, 'ReplicationStateTransition': {'acquireCount': {'w': 55}}, 'Global': {'acquireCount': {'r': 123, 'w': 9, 'W': 4}}, 'Database': {'acquireCount': {'r': 14, 'w': 3, 'W': 6}}, 'Collection': {'acquireCount': {'r': 20, 'w': 4, 'W': 2}}, 'Mutex': {'acquireCount': {'r': 24}}}, 'logicalSessionRecordCache': {'activeSessionsCount': 1, 'sessionsCollectionJobCount': 1, 'lastSessionsCollectionJobDurationMillis': 43, 'lastSessionsCollectionJobTimestamp': datetime.datetime(2025, 11, 28, 11, 46, 22, 309000), 'lastSessionsCollectionJobEntriesRefreshed': 0, 'lastSessionsCollectionJobEntriesEnded': 0, 'lastSessionsCollectionJobCursorsClosed': 0, 'transactionReaperJobCount': 1, 'lastTransactionReaperJobDurationMillis': 0, 'lastTransactionReaperJobTimestamp': datetime.datetime(2025, 11, 28, 11, 46, 22, 310000), 'lastTransactionReaperJobEntriesCleanedUp': 0, 'sessionCatalogSize': 0}, 'network': {'bytesIn': 1272, 'bytesOut': 1114, 'physicalBytesIn': 1272, 'physicalBytesOut': 1114, 'numSlowDNSOperations': 0, 'numSlowSSLOperations': 0, 'numRequests': 6, 'tcpFastOpen': {'kernelSetting': 1, 'serverSupported': True, 'clientSupported': True, 'accepted': 0}, 'compression': {'snappy': {'compressor': {'bytesIn': 0, 'bytesOut': 0}, 'decompressor': {'bytesIn': 0, 'bytesOut': 0}}, 'zstd': {'compressor': {'bytesIn': 0, 'bytesOut': 0}, 'decompressor': {'bytesIn': 0, 'bytesOut': 0}}, 'zlib': {'compressor': {'bytesIn': 0, 'bytesOut': 0}, 'decompressor': {'bytesIn': 0, 'bytesOut': 0}}}, 'serviceExecutorTaskStats': {'executor': 'passthrough', 'threadsRunning': 3}}, 'opLatencies': {'reads': {'latency': 0, 'ops': 0}, 'writes': {'latency': 0, 'ops': 0}, 'commands': {'latency': 346, 'ops': 4}, 'transactions': {'latency': 0, 'ops': 0}}, 'opReadConcernCounters': {'available': 0, 'linearizable': 0, 'local': 0, 'majority': 0, 'snapshot': 0, 'none': 1}, 'opcounters': {'insert': 0, 'query': 1, 'update': 0, 'delete': 0, 'getmore': 0, 'command': 9}, 'opcountersRepl': {'insert': 0, 'query': 0, 'update': 0, 'delete': 0, 'g ...
# Insert operation result: 69298ba9b7d70b04328393f2
# Read operation result: {'_id': ObjectId('69298ba9b7d70b04328393f2'), 'name': 'test', 'value': 123}

# %% [markdown]
# # 2 Preparations

# %% [markdown]
# Databases and collections in MongoDB are created implicitly while data is inserted. In this tutorial, you will create a collection of *films*. There is no collection so far, so create one by inserting a document.

# %%
query = """
db.films.insert({
    "title": "Star Trek Into Darkness",
    "year": 2013,
    "genre": [
        "Action",
        "Adventure",
        "Sci-Fi",
    ],
    "actors": [
        "Pine, Chris",
        "Quinto, Zachary",
        "Saldana, Zoe",
    ],
    "releases": [
        {
            "country": "USA",
            "date": ISODate("2013-05-17"),
            "prerelease": true
        },
        {
            "country": "Germany",
            "date": ISODate("2003-05-16"),
            "prerelease": false
        }
    ]
})"""

# !mongo --quiet --eval '{query}'
# Out:
# WriteResult({ "nInserted" : 1 })

# %% [markdown]
# Now, there is a *films* collection. You can list the contents of the newly created collection by calling the <code>find()</code> function.

# %%
#  To create a query

query = """db.films.find()"""

# !mongo --quiet --eval '{query}'
# Out:
# { "_id" : ObjectId("69298bccdfe5f020443ae9e5"), "title" : "Star Trek Into Darkness", "year" : 2013, "genre" : [ "Action", "Adventure", "Sci-Fi" ], "actors" : [ "Pine, Chris", "Quinto, Zachary", "Saldana, Zoe" ], "releases" : [ { "country" : "USA", "date" : ISODate("2013-05-17T00:00:00Z"), "prerelease" : true }, { "country" : "Germany", "date" : ISODate("2003-05-16T00:00:00Z"), "prerelease" : false } ] }
# { "_id" : ObjectId("69298bdbaebdb6e5c30d1c40"), "title" : "Star Trek Into Darkness", "year" : 2013, "genre" : [ "Action", "Adventure", "Sci-Fi" ], "actors" : [ "Pine, Chris", "Quinto, Zachary", "Saldana, Zoe" ], "releases" : [ { "country" : "USA", "date" : ISODate("2013-05-17T00:00:00Z"), "prerelease" : true }, { "country" : "Germany", "date" : ISODate("2003-05-16T00:00:00Z"), "prerelease" : false } ] }

# %% [markdown]
# If you prefer your result nicely formatted, use <code>pretty()</code>:

# %%
# To make the output into a more READABLE format

query = """db.films.find().pretty()"""

# !mongo --quiet --eval '{query}'
# Out:
# {
# 	"_id" : ObjectId("69298bccdfe5f020443ae9e5"),
# 	"title" : "Star Trek Into Darkness",
# 	"year" : 2013,
# 	"genre" : [
# 		"Action",
# 		"Adventure",
# 		"Sci-Fi"
# 	],
# 	"actors" : [
# 		"Pine, Chris",
# 		"Quinto, Zachary",
# 		"Saldana, Zoe"
# 	],
# 	"releases" : [
# 		{
# 			"country" : "USA",
# 			"date" : ISODate("2013-05-17T00:00:00Z"),
# 			"prerelease" : true
# 		},
# 		{
# 			"country" : "Germany",
# 			"date" : ISODate("2003-05-16T00:00:00Z"),
# 			"prerelease" : false
# 		}
# 	]
# }
# {
# 	"_id" : ObjectId("69298bdbaebdb6e5c30d1c40"),
# 	"title" : "Star Trek Into Darkness",
# 	"year" : 2013,
# 	"genre" : [
# 		"Action",
# 		"Adventure",
# 		"Sci-Fi"
# 	],
# 	"actors" : [
# 		"Pine, Chris",
# 		"Quinto, Zachary",
# 		"Saldana, Zoe"
# 	],
# 	"releases" : [
# 		{
# 			"country" : "USA",
# 			"date" : ISODate("2013-05-17T00:00:00Z"),
# 			"prerelease" : true
# 		},
# 		{
# 			"country" : "Germany",
# 			"date" : ISODate("2003-05-16T00:00:00Z"),
# 			"prerelease" : false
# 		}
# 	]
# }

# %% [markdown]
# As you can see, now there is an <code>_id</code> field which is unique for every document

# %% [markdown]
# Now insert some more films:

# %%
query = """
db.films.insert({
    "title": "Iron Man 3",
    "year": 2013,
    "genre": [
        "Action",
        "Adventure",
        "Sci-Fi",
    ],
    "actors": [
        "Downey Jr., Robert",
        "Paltrow, Gwyneth",
    ]
})
""" # no releases

# !mongo --quiet --eval '{query}'
# Out:
# WriteResult({ "nInserted" : 1 })

# %%
query = """
db.films.insert({
    "title": "This Means War",
    "year": 2011,
    "genre": [
        "Action",
        "Comedy",
        "Romance",
    ],
    "actors": [
        "Pine, Chris",
        "Witherspoon, Reese",
        "Hardy, Tom",
    ],
    "releases": [
        {
            "country": "USA",
            "date": ISODate("2011-02-17"),
            "prerelease": false
        },
        {
            "country": "UK" ,
            "date": ISODate("2011-03-01"),
            "prerelease": true
        }
    ]
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# WriteResult({ "nInserted" : 1 })

# %%
query = """
db.films.insert({
    "title": "The Amazing Spider - Man 2",
    "year": 2014,
    "genre": [
        "Action",
        "Adventure",
        "Fantasy",
    ],
    "actors": [
        "Stone, Emma" ,
        "Woodley, Shailene"
    ]
})
""" # also no releases

# !mongo --quiet --eval '{query}'
# Out:
# WriteResult({ "nInserted" : 1 })

# %% [markdown]
# # 3 Querying

# %% [markdown]
# Now query your collection! Have MongoDB return all films with title **"Iron Man 3"** by calling:

# %%
# Find one COLLECTION
query = """
db.films.find({"title": "Iron Man 3"}).pretty()
"""

# !mongo --quiet --eval '{query}'
# Out:
# {
# 	"_id" : ObjectId("69298d20179297008bd9826e"),
# 	"title" : "Iron Man 3",
# 	"year" : 2013,
# 	"genre" : [
# 		"Action",
# 		"Adventure",
# 		"Sci-Fi"
# 	],
# 	"actors" : [
# 		"Downey Jr., Robert",
# 		"Paltrow, Gwyneth"
# 	]
# }

# %% [markdown]
# Using <code>findOne</code> instead of find produces at most one result (in pretty format):

# %%
query = """
db.films.findOne({"title": "Iron Man 3"})
"""

# !mongo --quiet --eval '{query}'
# Out:
# {
# 	"_id" : ObjectId("69298d20179297008bd9826e"),
# 	"title" : "Iron Man 3",
# 	"year" : 2013,
# 	"genre" : [
# 		"Action",
# 		"Adventure",
# 		"Sci-Fi"
# 	],
# 	"actors" : [
# 		"Downey Jr., Robert",
# 		"Paltrow, Gwyneth"
# 	]
# }

# %% [markdown]
# Regular expressions can also be used to query a collection. In this tutorial, a short notation is used where the actual regular expression is bounded by slashes (/). The following call yields all movies that start with the letter T:

# %%
# To find "title that starts_with_T"
query = """
db.films.find({"title": /^T/})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "_id" : ObjectId("69298d23b86db9730e4b5f6e"), "title" : "This Means War", "year" : 2011, "genre" : [ "Action", "Comedy", "Romance" ], "actors" : [ "Pine, Chris", "Witherspoon, Reese", "Hardy, Tom" ], "releases" : [ { "country" : "USA", "date" : ISODate("2011-02-17T00:00:00Z"), "prerelease" : false }, { "country" : "UK", "date" : ISODate("2011-03-01T00:00:00Z"), "prerelease" : true } ] }
# { "_id" : ObjectId("69298d24effb143b345e8cfa"), "title" : "The Amazing Spider - Man 2", "year" : 2014, "genre" : [ "Action", "Adventure", "Fantasy" ], "actors" : [ "Stone, Emma", "Woodley, Shailene" ] }

# %%
# To find "title that starts_with_T" ,, this is more Explicit
query = """
db.films.find({"title": {"$regex": "^T"}})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "_id" : ObjectId("69298d23b86db9730e4b5f6e"), "title" : "This Means War", "year" : 2011, "genre" : [ "Action", "Comedy", "Romance" ], "actors" : [ "Pine, Chris", "Witherspoon, Reese", "Hardy, Tom" ], "releases" : [ { "country" : "USA", "date" : ISODate("2011-02-17T00:00:00Z"), "prerelease" : false }, { "country" : "UK", "date" : ISODate("2011-03-01T00:00:00Z"), "prerelease" : true } ] }
# { "_id" : ObjectId("69298d24effb143b345e8cfa"), "title" : "The Amazing Spider - Man 2", "year" : 2014, "genre" : [ "Action", "Adventure", "Fantasy" ], "actors" : [ "Stone, Emma", "Woodley, Shailene" ] }

# %% [markdown]
# If you are only interested in certain attributes, you can use projection to thin out the produced result. While the selection criteria are given by the first argument of find, the projection is given by the second argument. An example:

# %%
# Wants to Return ONLY the 'title'
query = """
db.films.find({
  "title": /^T/
},
{
  "title": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "_id" : ObjectId("69298d23b86db9730e4b5f6e"), "title" : "This Means War" }
# { "_id" : ObjectId("69298d24effb143b345e8cfa"), "title" : "The Amazing Spider - Man 2" }

# %%
# Control the OUTPUT,, The Projection part
query = """
db.films.find({
  "title": {"$regex": "^T"}
},
{
  "title": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "_id" : ObjectId("69298d23b86db9730e4b5f6e"), "title" : "This Means War" }
# { "_id" : ObjectId("69298d24effb143b345e8cfa"), "title" : "The Amazing Spider - Man 2" }

# %% [markdown]
# By default, the <code>_id</code> is part of the output, so you have to explicitly suppress it, if you don’t want to have it returned by MongoDB:

# %%
# To Remove the 'id'
query = """
db.films.find({
  "title": /^T/
},
{
  "_id": 0,
  "title": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "This Means War" }
# { "title" : "The Amazing Spider - Man 2" }

# %%
query = """
db.films.find({
  "title": {"$regex": "^T"}
},
{
  "_id": 0,
  "title": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "This Means War" }
# { "title" : "The Amazing Spider - Man 2" }

# %% [markdown]
# You can also use conditional operators, for example to perform range queries. The following returns the titles of all films starting with the letter T where the year attribute is greater than 2009 and less than or equal to 2011:

# %%
# To find smt greater_than (gt) 2009 + less_than_equal (lte) 2011
query = """
db.films.find({
    "year": {
        "$gt": 2009,
        "$lte": 2011
    },
    "title": /^T/
},
{
    "_id": 0,
    "title": 1,
    "year": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "This Means War", "year" : 2011 }

# %%
# To find smt greater_than (gt) 2009 + less_than_equal (lte) 2011,, Using the Regular Expression
query = """
db.films.find({
    "year": {
        "$gt": 2009,
        "$lte": 2011
    },
    "title": {"$regex": "^T"}
},
{
    "_id": 0,
    "title": 1,
    "year": 1

})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "This Means War", "year" : 2011 }

# %% [markdown]
# For a logical disjunction of the selection criteria, use the <code>$or</code> operator:

# %%
# To find smt greater_than (gt) 2009 + less_than_equal (lte) 2011
# To find "title that starts_with_T"
query = """
db.films.find({
    $or: [
      {
          "year": {
              "$gt": 2009,
              "$lte": 2011
          }
      },
      {
          "title": /^T/
      }
    ]
},
{
    "_id": 0,
    "title": 1,
    "year": 1

})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "This Means War", "year" : 2011 }
# { "title" : "The Amazing Spider - Man 2", "year" : 2014 }

# %%
# To find smt greater_than (gt) 2009 + less_than_equal (lte) 2011
# To find "title that starts_with_T" ,, Using the Regular Expresssion
query = """
db.films.find({
    $or: [
      {
          "year": {
              "$gt": 2009,
              "$lte": 2011
          }
      },
      {
          "title": {"$regex": "^T"}
      }
    ]
},
{
    "_id": 0,
    "title": 1,
    "year": 1

})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "This Means War", "year" : 2011 }
# { "title" : "The Amazing Spider - Man 2", "year" : 2014 }

# %% [markdown]
# There are also some options that can be appended to the regular expression, e.g. i to achieve caseinsensitivity. The following call returns the titles of all movies whose title contains lowercase t, ...

# %%
# To find a title that contains 't'
query = """
db.films.find({"title": /t/}, {"_id": 0, "title": 1})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "Star Trek Into Darkness" }
# { "title" : "Star Trek Into Darkness" }

# %%
# To find a title that contains 't',, Using the Regular Expression
query = """
db.films.find({
  "title": {"$regex": "t"}
},
{
  "_id": 0,
  "title": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "Star Trek Into Darkness" }
# { "title" : "Star Trek Into Darkness" }

# %% [markdown]
# ... whereas the following call also returns titles that contain a T (uppercase):

# %%
# For CASE SENSISTIVE
query = """
db.films.find({
  "title": /t/i
},
{
  "_id": 0,
  "title": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "Star Trek Into Darkness" }
# { "title" : "Star Trek Into Darkness" }
# { "title" : "This Means War" }
# { "title" : "The Amazing Spider - Man 2" }

# %%
# For CASE SENSISTIVE,, Using the Regular Expression
query = """
db.films.find({
  "title": {
    "$regex": "t",
    "$options": "i"
  }
},
{"_id": 0, "title": 1})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "Star Trek Into Darkness" }
# { "title" : "Star Trek Into Darkness" }

# %% [markdown]
# You can query for exact matches in lists, ...

# %%
# To find genres that has "Adventure" + returns "genre" as a List
query = """
db.films.find({
  "genre": "Adventure"
},
{
  "_id": 0,
  "title": 1,
  "genre": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "Star Trek Into Darkness", "genre" : [ "Action", "Adventure", "Sci-Fi" ] }
# { "title" : "Star Trek Into Darkness", "genre" : [ "Action", "Adventure", "Sci-Fi" ] }
# { "title" : "Iron Man 3", "genre" : [ "Action", "Adventure", "Sci-Fi" ] }
# { "title" : "The Amazing Spider - Man 2", "genre" : [ "Action", "Adventure", "Fantasy" ] }

# %% [markdown]
# ... but you can also query for partial matches which yields all genres that start with the letter A:

# %%
# To find genres that starts with 'A'
query = """
db.films.find({
  "genre": /^A/
},
{
  "_id": 0,
  "title": 1,
  "genre": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "Star Trek Into Darkness", "genre" : [ "Action", "Adventure", "Sci-Fi" ] }
# { "title" : "Star Trek Into Darkness", "genre" : [ "Action", "Adventure", "Sci-Fi" ] }
# { "title" : "Iron Man 3", "genre" : [ "Action", "Adventure", "Sci-Fi" ] }
# { "title" : "This Means War", "genre" : [ "Action", "Comedy", "Romance" ] }
# { "title" : "The Amazing Spider - Man 2", "genre" : [ "Action", "Adventure", "Fantasy" ] }

# %%
# To find genres that starts with 'A',, Using the Regular Expression
query = """
db.films.find({
  "genre": {"$regex": "^A"}
},
{
  "_id": 0,
  "title": 1,
  "genre": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "Star Trek Into Darkness", "genre" : [ "Action", "Adventure", "Sci-Fi" ] }
# { "title" : "Star Trek Into Darkness", "genre" : [ "Action", "Adventure", "Sci-Fi" ] }
# { "title" : "Iron Man 3", "genre" : [ "Action", "Adventure", "Sci-Fi" ] }
# { "title" : "This Means War", "genre" : [ "Action", "Comedy", "Romance" ] }
# { "title" : "The Amazing Spider - Man 2", "genre" : [ "Action", "Adventure", "Fantasy" ] }

# %% [markdown]
# There are also more complex operators for more complex selection criteria, e.g. the <code>$all</code> operator. The following call prints the title and actors of every movie for which each of two given regular expressions matches at least one of its actors:

# %%
# To find 2 actors with the word 'pine' n 'zachary'
# BOTH conditions MUST be satisfied
query = """
db.films.find({
    "actors": {
      "$all": [/pine/i, /zachary/i]
    }
},
{
    "_id": 0,
    "title": 1,
    "actors": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "Star Trek Into Darkness", "actors" : [ "Pine, Chris", "Quinto, Zachary", "Saldana, Zoe" ] }
# { "title" : "Star Trek Into Darkness", "actors" : [ "Pine, Chris", "Quinto, Zachary", "Saldana, Zoe" ] }

# %%
# To find 2 actors with the word 'pine' n 'zachary'
# BOTH conditions MUST be satisfied,, Using the Regular Expression
query = """
db.films.find({
    "actors": {
      $all: [
        {
          "$elemMatch": {"$regex": "pine", $options: "i"}
        },
        {
          "$elemMatch": {"$regex": "zachary", $options: "i"}
        }
      ]
    }
},
{
    "_id": 0,
    "title": 1,
    "actors": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "Star Trek Into Darkness", "actors" : [ "Pine, Chris", "Quinto, Zachary", "Saldana, Zoe" ] }
# { "title" : "Star Trek Into Darkness", "actors" : [ "Pine, Chris", "Quinto, Zachary", "Saldana, Zoe" ] }

# %% [markdown]
# In contrast, the <code>$nin</code>, i.e. not in, operator checks for the lack of matching values, i.e. actor names that do not match either one of the given regular expressions:

# %%
# To find films that does NOT contain 'pine' n 'zachary'
query = """
db.films.find({
    "actors": {
      $nin: [/pine/i, /zachary/i]
    }
},
{
    "_id": 0,
    "title": 1,
    "actors": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "Iron Man 3", "actors" : [ "Downey Jr., Robert", "Paltrow, Gwyneth" ] }
# { "title" : "The Amazing Spider - Man 2", "actors" : [ "Stone, Emma", "Woodley, Shailene" ] }

# %%
# To find films that does NOT contain 'pine' n 'zachary',, Using the Regular Expression
query = """
db.films.find({
    "actors": {
        $nor: [
            {$regex: "pine", $options: "i"},
            {$regex: "zachary", $options: "i"}
        ]
    }
},
{
    "_id": 0,
    "title": 1,
    "actors": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# Error: error: {
# 	"ok" : 0,
# 	"errmsg" : "unknown operator: $nor",
# 	"code" : 2,
# 	"codeName" : "BadValue"
# }

# %% [markdown]
# In this query: `$nor`: This operator performs a logical NOR operation on an array of one or more query expression and selects the documents that fail all the query expressions in the array.

# %% [markdown]
# The <code>$exists</code> operator can be used to check for the existence of an attribute, e.g. to select only movies with undefined releases:

# %%
query = """
db.films.find({
  releases: {$exists: false}
},
{
  "_id": 0,
  "title": 1,
  "releases": 1
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "title" : "Iron Man 3" }
# { "title" : "The Amazing Spider - Man 2" }

# %% [markdown]
# In MongoDB, it is also possible to query nested data, i.e. subdocuments. The following returns the title and releases of every movie that is known to be released in the UK:

# %%
# To find films that was released in 'UK'
query = """
db.films.find({
  "releases.country": "UK"
},
{
  "_id": 0,
  "title": 1,
  "releases": 1
}).pretty()
"""

# OUTPUT is in List
# to navigate DOWN, just add ".", to navigate DOWN

# !mongo --quiet --eval '{query}'
# Out:
# {
# 	"title" : "This Means War",
# 	"releases" : [
# 		{
# 			"country" : "USA",
# 			"date" : ISODate("2011-02-17T00:00:00Z"),
# 			"prerelease" : false
# 		},
# 		{
# 			"country" : "UK",
# 			"date" : ISODate("2011-03-01T00:00:00Z"),
# 			"prerelease" : true
# 		}
# 	]
# }

# %% [markdown]
# Please note that you have to use quotes to address nested fields.

# %% [markdown]
# Applying more complex selection criteria on a nested document, however, is a little tricky. For example, if you wanted MongoDB to return all movies that had their prerelease in the USA, you might try something like this:

# %%
query = """
db.films.find({
    "releases.country": "USA" ,
    "releases.prerelease": true
},
{
    "_id": 0 ,
    "title": 1,
    "releases": 1
}).pretty()
"""

# !mongo --quiet --eval '{query}'
# Out:
# {
# 	"title" : "Star Trek Into Darkness",
# 	"releases" : [
# 		{
# 			"country" : "USA",
# 			"date" : ISODate("2013-05-17T00:00:00Z"),
# 			"prerelease" : true
# 		},
# 		{
# 			"country" : "Germany",
# 			"date" : ISODate("2003-05-16T00:00:00Z"),
# 			"prerelease" : false
# 		}
# 	]
# }
# {
# 	"title" : "Star Trek Into Darkness",
# 	"releases" : [
# 		{
# 			"country" : "USA",
# 			"date" : ISODate("2013-05-17T00:00:00Z"),
# 			"prerelease" : true
# 		},
# 		{
# 			"country" : "Germany",
# 			"date" : ISODate("2003-05-16T00:00:00Z"),
# 			"prerelease" : false
# 		}
# 	]
# }
# {
# 	"title" : "This Means War",
# 	"releases" : [
# 		{
# 			"country" : "USA",
# 			"date" : ISODate("2011-02-17T00:00:00Z"),
# 			"prerelease" : false
# 		},
# 		{
# 			"country" : "UK",
# 			"date" : ISODate("2011-03-01T00:00:00Z"),
# 			"prerelease" : true
# 		}
# 	]
# }

# %% [markdown]
# However, This Means War is also returned, but was prereleased in the UK. The call above actually returns all movies that have some prerelease or were released in the USA. To only select movies were both applies to the same release, the <code>$elemMatch</code> can be used:

# %%
# elemMatch == Each element NEEDS to MATCH
query = """
db.films.find({
  releases: {
    $elemMatch: {
      country: "USA",
      prerelease: true
    }
  }
}).pretty()
"""

# !mongo --quiet --eval '{query}'
# Out:
# {
# 	"_id" : ObjectId("69298bccdfe5f020443ae9e5"),
# 	"title" : "Star Trek Into Darkness",
# 	"year" : 2013,
# 	"genre" : [
# 		"Action",
# 		"Adventure",
# 		"Sci-Fi"
# 	],
# 	"actors" : [
# 		"Pine, Chris",
# 		"Quinto, Zachary",
# 		"Saldana, Zoe"
# 	],
# 	"releases" : [
# 		{
# 			"country" : "USA",
# 			"date" : ISODate("2013-05-17T00:00:00Z"),
# 			"prerelease" : true
# 		},
# 		{
# 			"country" : "Germany",
# 			"date" : ISODate("2003-05-16T00:00:00Z"),
# 			"prerelease" : false
# 		}
# 	]
# }
# {
# 	"_id" : ObjectId("69298bdbaebdb6e5c30d1c40"),
# 	"title" : "Star Trek Into Darkness",
# 	"year" : 2013,
# 	"genre" : [
# 		"Action",
# 		"Adventure",
# 		"Sci-Fi"
# 	],
# 	"actors" : [
# 		"Pine, Chris",
# 		"Quinto, Zachary",
# 		"Saldana, Zoe"
# 	],
# 	"releases" : [
# 		{
# 			"country" : "USA",
# 			"date" : ISODate("2013-05-17T00:00:00Z"),
# 			"prerelease" : true
# 		},
# 		{
# 			"country" : "Germany",
# 			"date" : ISODate("2003-05-16T00:00:00Z"),
# 			"prerelease" : false
# 		}
# 	]
# }

# %% [markdown]
# Naturally, there are many other operators not covered by this tutorial.

# %% [markdown]
# # 4 Update

# %% [markdown]
# You can also add or update fields in a document by using the <code>$set</code> operator. For example, you can add a rating field to one of the movies:

# %%
# Adding a New Field
query = """
db.films.update(
    {"title": "Star Trek Into Darkness"},
    {$set: {"rating": 6.4}}
)
"""

# !mongo --quiet --eval '{query}'
# Out:
# WriteResult({ "nMatched" : 1, "nUpserted" : 0, "nModified" : 0 })

# %% [markdown]
# If you do not use the $set operator, every document fulfilling the selection criteria will be replaced, so be careful!

# %% [markdown]
# Now, verify if the <code>rating</code> field is added to the document:

# %%
query = """
db.films.find({
  "title": "Star Trek Into Darkness"
}).pretty()
"""

# !mongo --quiet --eval '{query}'
# Out:
# {
# 	"_id" : ObjectId("69298bccdfe5f020443ae9e5"),
# 	"title" : "Star Trek Into Darkness",
# 	"year" : 2013,
# 	"genre" : [
# 		"Action",
# 		"Adventure",
# 		"Sci-Fi"
# 	],
# 	"actors" : [
# 		"Pine, Chris",
# 		"Quinto, Zachary",
# 		"Saldana, Zoe"
# 	],
# 	"releases" : [
# 		{
# 			"country" : "USA",
# 			"date" : ISODate("2013-05-17T00:00:00Z"),
# 			"prerelease" : true
# 		},
# 		{
# 			"country" : "Germany",
# 			"date" : ISODate("2003-05-16T00:00:00Z"),
# 			"prerelease" : false
# 		}
# 	],
# 	"rating" : 6.4
# }
# {
# 	"_id" : ObjectId("69298bdbaebdb6e5c30d1c40"),
# 	"title" : "Star Trek Into Darkness",
# 	"year" : 2013,
# 	"genre" : [
# 		"Action",
# 		"Adventure",
# 		"Sci-Fi"
# 	],
# 	"actors" : [
# 		"Pine, Chris",
# 		"Quinto, Zachary",
# 		"Saldana, Zoe"
# 	],
# 	"releases" : [
# 		{
# 			"country" : "USA",
# 			"date" : ISODate("2013-05-17T00:00:00Z"),
# 			"prerelease" : true
# 		},
# 		{
# 			"country" : "Germany",
# 			"date" : ISODate("2003-05-16T00:00:00Z"),
# 			"prerelease" : false
# 		}
# 	]
# }

# %% [markdown]
# To increment a number of value, you can use the <code>$inc</code> operator:

# %%
query = """
db.films.update(
    {"title": "Star Trek Into Darkness"},
    {$inc: {"rating": 0.1}}
)
"""

# !mongo --quiet --eval '{query}'
# Out:
# WriteResult({ "nMatched" : 1, "nUpserted" : 0, "nModified" : 1 })

# %% [markdown]
# Verify if the rating value has been incremented by <code>0.1</code>.

# %%
query = """
db.films.find({
  "title": "Star Trek Into Darkness"
})
"""

# !mongo --quiet --eval '{query}'
# Out:
# { "_id" : ObjectId("69298bccdfe5f020443ae9e5"), "title" : "Star Trek Into Darkness", "year" : 2013, "genre" : [ "Action", "Adventure", "Sci-Fi" ], "actors" : [ "Pine, Chris", "Quinto, Zachary", "Saldana, Zoe" ], "releases" : [ { "country" : "USA", "date" : ISODate("2013-05-17T00:00:00Z"), "prerelease" : true }, { "country" : "Germany", "date" : ISODate("2003-05-16T00:00:00Z"), "prerelease" : false } ], "rating" : 6.6 }
# { "_id" : ObjectId("69298bdbaebdb6e5c30d1c40"), "title" : "Star Trek Into Darkness", "year" : 2013, "genre" : [ "Action", "Adventure", "Sci-Fi" ], "actors" : [ "Pine, Chris", "Quinto, Zachary", "Saldana, Zoe" ], "releases" : [ { "country" : "USA", "date" : ISODate("2013-05-17T00:00:00Z"), "prerelease" : true }, { "country" : "Germany", "date" : ISODate("2003-05-16T00:00:00Z"), "prerelease" : false } ] }

# %% [markdown]
# Again, there are many other different operators for different purposes, e.g. `$unset`, `$inc`, `$pop`, `$push`, `$pushAll` or `$addToSet`.

# %% [markdown]
# # 5 Delete

# %% [markdown]
# You can remove documents with the remove function. It actually works almost like the find function; you only don’t use the projection parameter. If, for example, you want to remove all film documents whose title starts with the letter T, you can first query for all such movies...

# %%
query = """
db.films.find({"title": /^T/}).pretty()
"""

# !mongo --quiet --eval '{query}'
# Out:
# {
# 	"_id" : ObjectId("69298d23b86db9730e4b5f6e"),
# 	"title" : "This Means War",
# 	"year" : 2011,
# 	"genre" : [
# 		"Action",
# 		"Comedy",
# 		"Romance"
# 	],
# 	"actors" : [
# 		"Pine, Chris",
# 		"Witherspoon, Reese",
# 		"Hardy, Tom"
# 	],
# 	"releases" : [
# 		{
# 			"country" : "USA",
# 			"date" : ISODate("2011-02-17T00:00:00Z"),
# 			"prerelease" : false
# 		},
# 		{
# 			"country" : "UK",
# 			"date" : ISODate("2011-03-01T00:00:00Z"),
# 			"prerelease" : true
# 		}
# 	]
# }
# {
# 	"_id" : ObjectId("69298d24effb143b345e8cfa"),
# 	"title" : "The Amazing Spider - Man 2",
# 	"year" : 2014,
# 	"genre" : [
# 		"Action",
# 		"Adventure",
# 		"Fantasy"
# 	],
# 	"actors" : [
# 		"Stone, Emma",
# 		"Woodley, Shailene"
# 	]
# }

# %% [markdown]
# ... to verify that your selection criteria is correct and then replaced the find in your call by remove:

# %%
# To REMOVE data
query = """
db.films.remove({"title": /^T/})
"""

# !mongo --quiet --eval '{query}'
# Out:
# WriteResult({ "nRemoved" : 0 })

# %% [markdown]
# Now, we verify if the documents has been removed from the collection:

# %%
query = """
db.films.find()
"""

# !mongo --quiet --eval '{query}'
